# %%
import pandas as pd

movies = pd.read_csv("../data/movies.csv")
ratings = pd.read_csv("../data/ratings.csv")

print(movies.shape)
print(ratings.shape)

movies.head()
# Out:
# (9742, 3)
# (100836, 4)
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_ratings = ratings.merge(
    movies,
    on="movieId"
)

movie_ratings.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print(movie_ratings.shape)

movie_ratings.sample(5)
# Out:
# (100836, 6)
#        userId  movieId  rating   timestamp  \
# 70384     448   135567     1.5  1498934619
# 74289     474     4464     3.0  1014924284
# 91302     592       15     4.0   837350747
# 69062     448     2571     2.0  1162753923
# 53247     352     1894     3.0  1493673900
#
#                                      title                    genres
# 70384  Independence Day: Resurgence (2016)   Action|Adventure|Sci-Fi
# 74289       Accidental Tourist, The (1988)      Comedy|Drama|Romance
# 91302              Cutthroat Island (1995)  Action|Adventure|Romance
# 69062                   Matrix, The (1999)    Action|Sci-Fi|Thriller
# 53247         Six Days Seven Nights (1998)  Adventure|Comedy|Romance

# %%
movie_stats = movie_ratings.groupby("title").agg(
    avg_rating=("rating", "mean"),
    rating_count=("rating", "count")
).reset_index()

movie_stats.head()
# Out:
#                                      title  avg_rating  rating_count
# 0                               '71 (2014)         4.0             1
# 1  'Hellboy': The Seeds of Creation (2004)         4.0             1
# 2                   'Round Midnight (1986)         3.5             2
# 3                      'Salem's Lot (2004)         5.0             1
# 4                'Til There Was You (1997)         4.0             2

# %%
popular_movies = movie_stats[
    movie_stats["rating_count"] >= 50
].sort_values(
    by="avg_rating",
    ascending=False
)

popular_movies.head(20)
# Out:
#                                                   title  avg_rating  \
# 7593                   Shawshank Redemption, The (1994)    4.429022
# 3499                              Godfather, The (1972)    4.289062
# 3011                                  Fight Club (1999)    4.272936
# 1961                              Cool Hand Luke (1967)    4.271930
# 2531  Dr. Strangelove or: How I Learned to Stop Worr...    4.268041
# 6999                                 Rear Window (1954)    4.261905
# 3500                     Godfather: Part II, The (1974)    4.259690
# 2334                               Departed, The (2006)    4.252336
# 3564                                  Goodfellas (1990)    4.250000
# 1593                                  Casablanca (1942)    4.240000
# 2163                            Dark Knight, The (2008)    4.238255
# 9119                         Usual Suspects, The (1995)    4.237745
# 6808                         Princess Bride, The (1987)    4.232394
# 8001          Star Wars: Episode IV - A New Hope (1977)    4.231076
# 7421                            Schindler's List (1993)    4.225000
# 563                               Apocalypse Now (1979)    4.219626
# 420                           American History X (1998)    4.217054
# 8002  Star Wars: Episode V - The Empire Strikes Back...    4.215640
# 1736                                   Chinatown (1974)    4.211864
# 6944  Raiders of the Lost Ark (Indiana Jones and the...    4.207500
#
#       rating_count
# 7593           317
# 3499           192
# 3011           218
# 1961            57
# 2531            97
# 6999            84
# 3500           129
# 2334           107
# 3564           126
# 1593           100
# 2163           149
# 9119           204
# 6808           142
# 8001           251
# 7421           220
# 563            107
# 420            129
# 8002           211
# 1736            59
# 6944           200

# %%
user_movie_matrix = movie_ratings.pivot_table(
    index="userId",
    columns="title",
    values="rating"
)

user_movie_matrix.shape
# Out:
# (610, 9719)

# %% [markdown]
# ## Business Insight
#
# The Shawshank Redemption received the highest average rating among movies with at least 50 ratings, indicating strong user satisfaction and broad audience appeal.
#
# The user-movie matrix transformed 100,836 ratings into a structure suitable for recommendation modeling, with 610 users and 9,719 movies.

# %% [markdown]
# # Collaborative Filtering Recommendation Engine

# %%
ratings_with_movies = ratings.merge(movies, on="movieId")

movie_stats_fixed = ratings_with_movies.groupby("title").agg(
    avg_rating=("rating", "mean"),
    rating_count=("rating", "count")
)

toy_story_ratings = user_movie_matrix["Toy Story (1995)"]

similar_movies = user_movie_matrix.corrwith(toy_story_ratings)

corr_toy_story = pd.DataFrame(
    similar_movies,
    columns=["Correlation"]
)

corr_toy_story.dropna(inplace=True)

corr_toy_story = corr_toy_story.join(movie_stats_fixed["rating_count"])

recommendations = corr_toy_story[
    corr_toy_story["rating_count"] > 100
].sort_values(
    by="Correlation",
    ascending=False
)

recommendations.head(10)
# Out:
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3015: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
#                                                     Correlation  rating_count
# title
# Toy Story (1995)                                       1.000000           215
# Incredibles, The (2004)                                0.643301           125
# Finding Nemo (2003)                                    0.618701           141
# Aladdin (1992)                                         0.611892           183
# Monsters, Inc. (2001)                                  0.490231           132
# Mrs. Doubtfire (1993)                                  0.446261           144
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...     0.438237           120
# American Pie (1999)                                    0.420117           103
# Die Hard: With a Vengeance (1995)                      0.410939           144
# E.T. the Extra-Terrestrial (1982)                      0.409216           122

# %%
def get_recommendations(movie_title, min_rating_count=100, num_recommendations=10):
    movie_user_ratings = user_movie_matrix[movie_title]
    
    similar_movies = user_movie_matrix.corrwith(movie_user_ratings)
    
    recommendations = pd.DataFrame(
        similar_movies,
        columns=["Correlation"]
    )
    
    recommendations.dropna(inplace=True)
    
    recommendations = recommendations.join(movie_stats_fixed["rating_count"])
    
    recommendations = recommendations[
        recommendations["rating_count"] >= min_rating_count
    ].sort_values(
        by="Correlation",
        ascending=False
    )
    
    return recommendations.head(num_recommendations)

# %% [markdown]
# # Collaborative Filtering Recommendations

# %%
toy_story_ratings = user_movie_matrix["Toy Story (1995)"]

toy_story_ratings.head()
# Out:
# userId
# 1    4.0
# 2    NaN
# 3    NaN
# 4    NaN
# 5    4.0
# Name: Toy Story (1995), dtype: float64

# %%
similar_movies = user_movie_matrix.corrwith(toy_story_ratings)

similar_movies.head()
# Out:
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3015: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# title
# '71 (2014)                                NaN
# 'Hellboy': The Seeds of Creation (2004)   NaN
# 'Round Midnight (1986)                    NaN
# 'Salem's Lot (2004)                       NaN
# 'Til There Was You (1997)                 NaN
# dtype: float64

# %%
corr_toy_story = pd.DataFrame(
    similar_movies,
    columns=["Correlation"]
)

corr_toy_story.dropna(inplace=True)

corr_toy_story.head()
# Out:
#                                 Correlation
# title
# 'burbs, The (1989)                 0.240563
# (500) Days of Summer (2009)        0.353833
# *batteries not included (1987)    -0.427425
# 10 Cent Pistol (2015)              1.000000
# 10 Cloverfield Lane (2016)        -0.285732

# %%
movie_stats_fixed = movie_ratings.groupby("title").agg(
    avg_rating=("rating", "mean"),
    rating_count=("rating", "count")
)

movie_stats_fixed.head()
# Out:
#                                          avg_rating  rating_count
# title
# '71 (2014)                                      4.0             1
# 'Hellboy': The Seeds of Creation (2004)         4.0             1
# 'Round Midnight (1986)                          3.5             2
# 'Salem's Lot (2004)                             5.0             1
# 'Til There Was You (1997)                       4.0             2

# %%
corr_toy_story = corr_toy_story.join(
    movie_stats_fixed["rating_count"]
)

corr_toy_story.head()
# Out:
#                                 Correlation  rating_count
# title
# 'burbs, The (1989)                 0.240563            17
# (500) Days of Summer (2009)        0.353833            42
# *batteries not included (1987)    -0.427425             7
# 10 Cent Pistol (2015)              1.000000             2
# 10 Cloverfield Lane (2016)        -0.285732            14

# %%
recommendations = corr_toy_story[
    corr_toy_story["rating_count"] > 100
].sort_values(
    by="Correlation",
    ascending=False
)

recommendations.head(10)
# Out:
#                                                     Correlation  rating_count
# title
# Toy Story (1995)                                       1.000000           215
# Incredibles, The (2004)                                0.643301           125
# Finding Nemo (2003)                                    0.618701           141
# Aladdin (1992)                                         0.611892           183
# Monsters, Inc. (2001)                                  0.490231           132
# Mrs. Doubtfire (1993)                                  0.446261           144
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...     0.438237           120
# American Pie (1999)                                    0.420117           103
# Die Hard: With a Vengeance (1995)                      0.410939           144
# E.T. the Extra-Terrestrial (1982)                      0.409216           122

# %% [markdown]
# ## Recommendation Insight
#
# Using collaborative filtering, the model identified movies that share similar user rating patterns with Toy Story (1995).
#
# Top recommendations included:
#
# - The Incredibles
# - Finding Nemo
# - Aladdin
# - Monsters, Inc.
# - Mrs. Doubtfire
#
# This demonstrates how recommendation systems can identify related content based on user behavior rather than relying solely on movie genres or metadata.

# %%
get_recommendations("Toy Story (1995)")
# Out:
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3015: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
#                                                     Correlation  rating_count
# title
# Toy Story (1995)                                       1.000000           215
# Incredibles, The (2004)                                0.643301           125
# Finding Nemo (2003)                                    0.618701           141
# Aladdin (1992)                                         0.611892           183
# Monsters, Inc. (2001)                                  0.490231           132
# Mrs. Doubtfire (1993)                                  0.446261           144
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...     0.438237           120
# American Pie (1999)                                    0.420117           103
# Die Hard: With a Vengeance (1995)                      0.410939           144
# E.T. the Extra-Terrestrial (1982)                      0.409216           122

# %%
get_recommendations("Jurassic Park (1993)")
# Out:
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3015: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\jmerc\netflix-recommendation-engine\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
#                                                     Correlation  rating_count
# title
# Jurassic Park (1993)                                   1.000000           238
# Outbreak (1995)                                        0.533780           101
# Ghostbusters (a.k.a. Ghost Busters) (1984)             0.522286           120
# Fugitive, The (1993)                                   0.460603           190
# Indiana Jones and the Temple of Doom (1984)            0.456533           108
# Mission: Impossible (1996)                             0.451929           162
# Die Hard (1988)                                        0.451241           145
# X-Men (2000)                                           0.448910           133
# Twister (1996)                                         0.440167           123
# Raiders of the Lost Ark (Indiana Jones and the ...     0.437401           200
